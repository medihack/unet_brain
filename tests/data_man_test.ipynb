# %%
import numpy as np
import os
import sys

module_path = os.path.abspath(os.path.join('../src'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from utils import VolSegDataManager
from utils import show_sample
from utils import show_batch
from utils import to_numerical
# Out:
# Using TensorFlow backend.

# %%
data = VolSegDataManager('../data', vol_prefix='vol_', seg_prefix='seg_', test_fract=0.34)
# Out:
# Data Manager: got 3 volume / segmentation file pairs
# Data Manager: using 2 samples as training data
# Data Manager: using 1 samples as test/validation data

# %%
gen_train = data.get_train_batch_generator()
gen_test = data.get_test_batch_generator()

# %%
batch = gen_train.next()
# Out:
# Data Manager: loading sample with index 1

# %%
vol_batch, seg_batch = batch

# %%
vol = vol_batch[0]
seg = seg_batch[0]

# %%
vol.shape
# Out:
# (176, 208, 176, 1)

# %%
seg.shape
# Out:
# (176, 208, 176, 4)

# %%
show_batch(vol_batch, seg_batch)

# %%
show_batch(vol_batch, seg_batch)
